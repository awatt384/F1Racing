# %%
import pandas as pd

# %%
import numpy as mp

# %%
data = pd.read_csv ('drivers.csv', index_col=0)
#loaded data

# %%
data.head(3)
#first 3 rows
# Out:
#          driverRef number code forename   surname         dob nationality  \
# driverId
# 1         hamilton     44  HAM    Lewis  Hamilton  1985-01-07     British
# 2         heidfeld     \N  HEI     Nick  Heidfeld  1977-05-10      German
# 3          rosberg      6  ROS     Nico   Rosberg  1985-06-27      German
#
#                                                   url
# driverId
# 1         http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2          http://en.wikipedia.org/wiki/Nick_Heidfeld
# 3           http://en.wikipedia.org/wiki/Nico_Rosberg

# %%
data.tail(2)
#last 3 rows
# Out:
#                 driverRef number code forename     surname         dob  \
# driverId
# 854       mick_schumacher     47  MSC     Mick  Schumacher  1999-03-22
# 855                  zhou     24  ZHO   Guanyu        Zhou  1999-05-30
#
#          nationality                                           url
# driverId
# 854           German  http://en.wikipedia.org/wiki/Mick_Schumacher
# 855          Chinese      http://en.wikipedia.org/wiki/Guanyu_Zhou

# %%
data.rename(columns = {'driverId': 'DriverID', 'number': 'DriverNumber', 'code': 'DriverCode', 'forename': 'FirstName', 'surname': 'LastName', 'dob': 'DOB', 'nationality': 'Nationality' })
#cleaning up column names
# Out:
#                 driverRef DriverNumber DriverCode FirstName    LastName  \
# driverId
# 1                hamilton           44        HAM     Lewis    Hamilton
# 2                heidfeld           \N        HEI      Nick    Heidfeld
# 3                 rosberg            6        ROS      Nico     Rosberg
# 4                  alonso           14        ALO  Fernando      Alonso
# 5              kovalainen           \N        KOV    Heikki  Kovalainen
# ...                   ...          ...        ...       ...         ...
# 851                aitken           89        AIT      Jack      Aitken
# 852               tsunoda           22        TSU      Yuki     Tsunoda
# 853               mazepin            9        MAZ    Nikita     Mazepin
# 854       mick_schumacher           47        MSC      Mick  Schumacher
# 855                  zhou           24        ZHO    Guanyu        Zhou
#
#                  DOB Nationality  \
# driverId
# 1         1985-01-07     British
# ...

# %%
len(data)
# Out:
# 854

# %%
data.dtypes
# Out:
# driverRef      object
# number         object
# code           object
# forename       object
# surname        object
# dob            object
# nationality    object
# url            object
# dtype: object

# %%
data.drop (['url'], axis=1)
#Cleaning up data
# Out:
#                 driverRef number code  forename     surname         dob  \
# driverId
# 1                hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 2                heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 3                 rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 4                  alonso     14  ALO  Fernando      Alonso  1981-07-29
# 5              kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ...                   ...    ...  ...       ...         ...         ...
# 851                aitken     89  AIT      Jack      Aitken  1995-09-23
# 852               tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 853               mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 854       mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 855                  zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
#          nationality
# driverId
# 1            British
# 2             German
# ...

# %%
data.rename(columns = {'driverId': 'Driver ID', 'driverRef': 'Reference', 'number': 'Driver Number', 'code': 'Driver Code', 'forename': 'First Name', 'surname': 'Last Name', 'dob': 'DOB', 'nationality': 'Nationality'})
# Out:
#                 Reference Driver Number Driver Code First Name   Last Name  \
# driverId
# 1                hamilton            44         HAM      Lewis    Hamilton
# 2                heidfeld            \N         HEI       Nick    Heidfeld
# 3                 rosberg             6         ROS       Nico     Rosberg
# 4                  alonso            14         ALO   Fernando      Alonso
# 5              kovalainen            \N         KOV     Heikki  Kovalainen
# ...                   ...           ...         ...        ...         ...
# 851                aitken            89         AIT       Jack      Aitken
# 852               tsunoda            22         TSU       Yuki     Tsunoda
# 853               mazepin             9         MAZ     Nikita     Mazepin
# 854       mick_schumacher            47         MSC       Mick  Schumacher
# 855                  zhou            24         ZHO     Guanyu        Zhou
#
#                  DOB Nationality  \
# driverId
# ...

# %%
data.drop (['url'], axis=1)
#dropping url column
# Out:
#                 driverRef number code  forename     surname         dob  \
# driverId
# 1                hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 2                heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 3                 rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 4                  alonso     14  ALO  Fernando      Alonso  1981-07-29
# 5              kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ...                   ...    ...  ...       ...         ...         ...
# 851                aitken     89  AIT      Jack      Aitken  1995-09-23
# 852               tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 853               mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 854       mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 855                  zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
#          nationality
# driverId
# 1            British
# 2             German
# ...

# %%
data.iloc[0:1, 0:2] 
#specifi data point - calling row 1 positions 0-2 
#which is driverid driver ref and number 0,1,2
# Out:
#          driverRef number
# driverId
# 1         hamilton     44

# %%
data.sort_values(by=['driverId'])
#sort - asc
# Out:
#                 driverRef number code  forename     surname         dob  \
# driverId
# 1                hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 2                heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 3                 rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 4                  alonso     14  ALO  Fernando      Alonso  1981-07-29
# 5              kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ...                   ...    ...  ...       ...         ...         ...
# 851                aitken     89  AIT      Jack      Aitken  1995-09-23
# 852               tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 853               mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 854       mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 855                  zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
#          nationality                                             url
# driverId
# ...

# %%
data.groupby('nationality').count() 
#groupby to visualize nationality for global sponsorship
# Out:
#                    driverRef  number  code  forename  surname  dob  url
# nationality
# American                 157     157   157       157      157  157  157
# American-Italian           1       1     1         1        1    1    1
# Argentine                 24      24    24        24       24   24   24
# Argentine-Italian          1       1     1         1        1    1    1
# Australian                17      17    17        17       17   17   17
# Austrian                  15      15    15        15       15   15   15
# Belgian                   23      23    23        23       23   23   23
# Brazilian                 32      32    32        32       32   32   32
# British                  165     165   165       165      165  165  165
# Canadian                  14      14    14        14       14   14   14
# Chilean                    1       1     1         1        1    1    1
# Chinese                    1       1     1         1        1    1    1
# ...

# %%
data['nationality'].describe() #using column/dataframe nationality, describing the total 854, top british, and amount of occurances
# Out:
# count         854
# unique         42
# top       British
# freq          165
# Name: nationality, dtype: object

# %%
data.plot(x ='nationality', y='dob', kind = 'scatter') #using nationality and dob to create a chart as requested using scatter
# Out:
# <AxesSubplot:xlabel='nationality', ylabel='dob'>
